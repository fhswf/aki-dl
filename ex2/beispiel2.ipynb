# %% [markdown]
# # Beispiel Notebook 2
#
# Dies ist ein weiteres Beispiel-Notebook. Es zeigt dieselbe Struktur wie Beispiel 1: eine kurze Aufgabenbeschreibung und direkt darunter eine ausführbare Lösung in einer Code-Zelle.
#
# **Aufgabe**
# Implementiere die Funktion `square_numbers(values)`, die eine Liste von Zahlen entgegennimmt und die quadrierten Werte als neue Liste zurückgibt.

# %%
# YOUR CODE HERE
raise NotImplementedError()

square_numbers([1, 2, 3, 4])
