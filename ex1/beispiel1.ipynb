# %% [markdown]
# # Beispiel Notebook 1
#
# Dies ist ein Beispiel-Notebook. Unten ist eine Aufgabe und eine Lösung, die von nbgrader entfernt werden würde.
#
# **Aufgabe**
# Implementiere die Funktion `quadratic_roots(a, b, c)`, die die reellen Wurzeln der quadratischen Gleichung $ax^2 + bx + c = 0$ als Liste zurückgibt.

# %%
# YOUR CODE HERE
raise NotImplementedError()

quadratic_roots(1, -3, 2)
